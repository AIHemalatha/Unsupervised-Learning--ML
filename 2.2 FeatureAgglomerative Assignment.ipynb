# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = dataset.iloc[:, 3:5].values

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title("Dendrogram")
plt.xlabel("Customers")
plt.ylabel("Euclidean distances")
plt.show()

# %%
from sklearn import datasets, cluster
digits = datasets.load_digits()
images = digits.images
X = np.reshape(images, (len(images), -1))
clusmodel = cluster.FeatureAgglomeration(n_clusters=5)
label = clusmodel.fit(X)

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['Cluster_group']=label

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#                           Cluster_group
# 0    FeatureAgglomeration(n_clusters=5)
# 1    FeatureAgglomeration(n_clusters=5)
# 2    FeatureAgglomeration(n_clusters=5)
# 3    FeatureAgglomeration(n_clusters=5)
# 4    FeatureAgglomeration(n_clusters=5)
# ..                                  ...
# 195  FeatureAgglomeration(n_clusters=5)
# 196  FeatureAgglomeration(n_clusters=5)
# 197  FeatureAgglomeration(n_clusters=5)
# 198  FeatureAgglomeration(n_clusters=5)
# 199  FeatureAgglomeration(n_clusters=5)
#
# [200 rows x 6 columns]

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5], 
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Anaconda\envs\aidl\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
